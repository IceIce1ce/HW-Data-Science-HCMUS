# %% [markdown]
# # HW2: Khám phá dữ liệu, tiền xử lý, phân tích đơn giản
# **Vì đây là bài tập về Pandas nên yêu cầu là không được dùng vòng lặp**
#
# (Cập nhật lần cuối: 25/07/2021)
#
# Họ tên: Trần Đại Chí
#
# MSSV: 18127070

# %% [markdown]
# ---

# %% [markdown]
# ## Cách làm bài và nộp bài (bạn cần đọc kỹ)

# %% [markdown]
# &#9889; Bạn lưu ý là mình sẽ dùng chương trình hỗ trợ chấm bài nên bạn cần phải tuân thủ chính xác qui định mà mình đặt ra, nếu không rõ thì hỏi, chứ không nên tự tiện làm theo ý của cá nhân.
#
# **Cách làm bài**
#
# Bạn sẽ làm trực tiếp trên file notebook này. Đầu tiên, bạn điền họ tên và MSSV vào phần đầu file ở bên trên. Trong file, bạn làm bài ở những chỗ có ghi là:
# ```python
# # YOUR CODE HERE
# raise NotImplementedError()
# ```
# hoặc đối với những phần code không bắt buộc thì là:
# ```python
# # YOUR CODE HERE (OPTION)
# ```
# hoặc đối với markdown cell thì là:
# ```markdown
# YOUR ANSWER HERE
# ```
# Tất nhiên, khi làm thì bạn xóa dòng `raise NotImplementedError()` đi.
# Đối những phần yêu cầu code thì thường ở ngay phía dưới sẽ có một (hoặc một số) cell chứa các bộ test để giúp bạn biết đã code đúng hay chưa; nếu chạy cell này không có lỗi gì thì có nghĩa là qua được các bộ test. Trong một số trường hợp, các bộ test có thể sẽ không đầy đủ; nghĩa là, nếu không qua được test thì là code sai, nhưng nếu qua được test thì chưa chắc đã đúng.
#
# Trong khi làm bài, bạn có thể cho in ra màn hình, tạo thêm các cell để test. Nhưng khi nộp bài thì bạn xóa các cell mà bạn tự tạo, xóa hoặc comment các câu lệnh in ra màn hình. Bạn lưu ý <font color=red>không được tự tiện xóa các cell hay sửa code của Thầy</font> (trừ những chỗ được phép sửa như đã nói ở trên).
#
# Trong khi làm bài, thường xuyên `Ctrl + S` để lưu lại bài làm của bạn, tránh mất mát thông tin.
#
#
# *Nên nhớ mục tiêu chính ở đây là <font color=green>học, học một cách chân thật</font>. Bạn có thể thảo luận ý tưởng với bạn khác cũng như tham khảo các nguồn trên mạng, nhưng sau cùng <font color=green>code và bài làm phải là của bạn, dựa trên sự hiểu thật sự của bạn</font>. Khi tham khảo các nguồn trên mạng thì bạn cần ghi rõ nguồn trong bài làm. Bạn không được tham khảo bài làm của các bạn năm trước (vì nếu làm vậy thì bao giờ bạn mới có thể tự mình suy nghĩ để giải quyết vấn đề); sau khi kết thúc môn học, bạn cũng không được đưa bài làm cho các bạn khóa sau hoặc public bài làm trên Github (vì nếu làm vậy thì sẽ ảnh hưởng tới việc học của các bạn khóa sau). Nếu bạn có thể làm theo những gì mình nói thì điểm của bạn có thể sẽ không cao nhưng bạn sẽ có được những bước tiến thật sự. <font color=red>Trong trường hợp bạn vi phạm những điều mình nói ở trên thì sẽ bị 0 điểm cho toàn bộ môn học.</font>*
#
# **Cách nộp bài**
#
# Khi chấm bài, đầu tiên mình sẽ chọn `Kernel` - `Restart & Run All`, để restart và chạy tất cả các cell trong notebook của bạn; do đó, trước khi nộp bài, bạn nên chạy thử `Kernel` - `Restart & Run All` để đảm bảo mọi chuyện diễn ra đúng như mong đợi.
#
# Sau đó, bạn tạo thư mục nộp bài theo cấu trúc sau:
# - Thư mục `MSSV` (vd, nếu bạn có MSSV là 1234567 thì bạn đặt tên thư mục là `1234567`)
#     - File `HW2.ipynb` (không cần nộp các file khác)
#
# Cuối cùng, bạn nén thư mục `MSSV` này lại và nộp ở link trên moodle. Đuôi của file nén phải là .zip (chứ không được .rar hay gì khác).
#
# <font color=red>Bạn lưu ý tuân thủ chính xác qui định nộp bài ở trên.</font>

# %% [markdown]
# ---

# %% [markdown]
# ## Môi trường code

# %% [markdown]
# Ta thống nhất trong môn này: dùng phiên bản các package như trong file "min_ds-env.yml" (file này đã được cập nhật một số lần, file mới nhất ở đầu có dòng: "Last update: 24/06/2021"). Cách tạo ra môi trường code từ file "min_ds-env.yml" đã được nói ở file "02_BeforeClass-Notebook_Python.pdf".

# %% [markdown]
# Check môi trường code:

# %%
import sys
sys.executable
# Out:
# 'c:\\program files\\python36\\python.exe'

# %% [markdown]
# Nếu không có vấn đề gì thì file chạy python sẽ là file của môi trường code "min_ds-env".

# %% [markdown]
# ---

# %% [markdown]
# ## Import

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
# YOUR CODE HERE (OPTION) 
# Nếu cần các thư viện khác thì bạn có thể import ở đây
# Out:
# c:\program files\python36\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# c:\program files\python36\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
# c:\program files\python36\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   stacklevel=1)

# %% [markdown]
# ---

# %% [markdown]
# ## Thu thập dữ liệu

# %% [markdown]
# Dữ liệu được sử dụng trong bài tập này là dữ liệu khảo sát các lập trình viên của trang StackOverflow. Mình download dữ liệu [ở đây](https://drive.google.com/file/d/1dfGerWeWkcyQ9GX9x20rdSGj7WtEpzBB/view) và có bỏ đi một số cột để đơn giản hóa.
#
# Theo mô tả trong file "README_2020.txt" của StackOverflow:
# >The enclosed data set is the full, cleaned results of the 2020 Stack Overflow Developer Survey. Free response submissions and personally identifying information have been removed from the results to protect the privacy of respondents. There are three files besides this README:
# >
# >1. survey_results_public.csv - CSV file with main survey results, one respondent per row and one column per answer
# >2. survey_results_schema.csv - CSV file with survey schema, i.e., the questions that correspond to each column name
# >3. so_survey_2020.pdf - PDF file of survey instrument
# >
# >The survey was fielded from February 5 to February 28, 2020. The median time spent on the survey for qualified responses was 16.6 minutes.
# >
# >Respondents were recruited primarily through channels owned by Stack Overflow. The top 5 sources of respondents were onsite messaging, blog posts, email lists, Meta posts, banner ads, and social media posts. Since respondents were recruited in this way, highly engaged users on Stack Overflow were more likely to notice the links for the survey and click to begin it.
#
# File "survey_results_public-short.csv" mà mình đính kèm là phiên bản đơn giản hóa của file "survey_results_public.csv" (từ 61 cột, mình bỏ xuống còn 29 cột). Đây là file dữ liệu chính mà bạn sẽ làm trong bài tập này. Ngoài ra, mình còn đính kèm 2 file phụ: (1) file "survey_results_schema-short.csv" là file cho biết ý nghĩa của các cột, và (2) file "so_survey_2020.pdf" là file khảo sát gốc của StackOverflow.
#
# Để ý:
# - Dữ liệu này không đại diện được cho cộng đồng lập trình viên trên toàn thế giới, mà chỉ giới hạn trong tập những lập trình viên thực hiện khảo sát của StackOverflow. Những câu trả lời có được thông qua tập dữ liệu này cũng sẽ bị giới hạn trong phạm vi đó.
# - Dữ liệu có đúng không? Về cơ bản là ta không biết được. Ở đây, mục đích chính là học qui trình Khoa Học Dữ Liệu và các câu lệnh của Pandas nên ta sẽ **giả định** phần lớn dữ liệu là đúng và tiếp tục làm.
#
# Cũng theo file "README_2020.txt", dữ liệu này được StackOverflow public với license như sau:
# >This database - The Public 2020 Stack Overflow Developer Survey Results - is made available under the Open Database License (ODbL): http://opendatacommons.org/licenses/odbl/1.0/. Any rights in individual contents of the database are licensed under the Database Contents License: http://opendatacommons.org/licenses/dbcl/1.0/
# >
# >TLDR: You are free to share, adapt, and create derivative works from The Public 2020 Stack Overflow Developer Survey Results as long as you attribute Stack Overflow, keep the database open (if you redistribute it), and continue to share-alike any adapted database under the ODbl.

# %% [markdown]
# ---

# %% [markdown]
# ## Khám phá dữ liệu

# %% [markdown]
# ### Đọc dữ liệu từ file (0.25đ)

# %% [markdown]
# Đầu tiên, bạn viết code để đọc dữ liệu từ file "survey_results_public-short.csv" và lưu kết quả vào DataFrame `survey_df`; ta thống nhất là sẽ để file dữ liệu này cùng cấp với file notebook và khi đọc file thì chỉ truyền vào tên của file. Ngoài ra, bạn cũng cần cho cột `Respondent` (id của người làm khảo sát) làm cột index của `survey_df`.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
survey_df = pd.read_csv('survey_results_public-short.csv', index_col='Respondent')

# %%
# TEST
survey_df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#             ConvertedComp             Country  \
# Respondent
# 1                     NaN             Germany
# 2                     NaN      United Kingdom
# 3                     NaN  Russian Federation
# 4                     NaN             Albania
# 5                     NaN       United States
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
# 3                                                         NaN
# 4                                                         NaN
# 5                                                         NaN
#
#                                                     EdLevel  \
# Respondent
# 1           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                                       NaN
# 4           Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                    Employment  \
# Respondent
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Employed full-time
# 3                                                         NaN
# 4                                                         NaN
# 5                                          Employed full-time
#
#                                Ethnicity Gender  ...  \
# Respondent                                       ...
# 1           White or of European descent    Man  ...
# 2                                    NaN    NaN  ...
# 3                                    NaN    NaN  ...
# 4           White or of European descent    Man  ...
# 5           White or of European descent    Man  ...
#
#                                      NEWEdImpt       NEWLearn  \
# Respondent
# 1                             Fairly important    Once a year
# 2                             Fairly important    Once a year
# 3                                          NaN  Once a decade
# 4           Not at all important/not necessary    Once a year
# 5                               Very important    Once a year
#
#                                                   NEWOvertime  \
# Respondent
# 1                            Often: 1-2 days per week or more
# 2                                                         NaN
# 3                                                         NaN
# 4           Occasionally: 1-2 days per quarter but less th...
# 5                                                         NaN
#
#                                                      NEWStuck        OpSys  \
# Respondent
# 1           Visit Stack Overflow;Go for a walk or other ph...      Windows
# 2           Visit Stack Overflow;Go for a walk or other ph...        MacOS
# 3                                                         NaN  Linux-based
# 4                                                         NaN  Linux-based
# 5           Call a coworker or friend;Visit Stack Overflow...      Windows
#
#                                        PlatformDesireNextYear  \
# Respondent
# 1              Android;iOS;Kubernetes;Microsoft Azure;Windows
# 2                                  iOS;Kubernetes;Linux;MacOS
# 3                                                         NaN
# 4                                                         NaN
# 5           Docker;Google Cloud Platform;Heroku;Linux;Windows
#
#                         PlatformWorkedWith WorkWeekHrs YearsCode YearsCodePro
# Respondent
# 1                                  Windows        50.0        36           27
# 2                                      iOS         NaN         7            4
# 3                                      NaN         NaN         4          NaN
# 4                                      NaN        40.0         7            4
# 5           AWS;Docker;Linux;MacOS;Windows         NaN        15            8
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Dữ liệu có bao nhiêu dòng và bao nhiêu cột? (0.25đ)

# %% [markdown]
# Kế đến, bạn tính số dòng và số cột của DataFrame `survey_df` và lần lượt lưu vào biến `num_rows` và `num_cols`.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
num_rows = survey_df.shape[0]
num_cols = survey_df.shape[1]
print(str(num_rows) + ', ' + str(num_cols))
# Out:
# 64461, 28

# %%
# TEST
assert num_rows == 64461
assert num_cols == 28

# %% [markdown]
# ### Mỗi dòng có ý nghĩa gì? Có vấn đề các dòng có ý nghĩa khác nhau không?

# %% [markdown]
# Theo file "README_2020.txt" cũng như theo quan sát sơ bộ về dữ liệu, mỗi dòng trong DataFrame `survey_df` cho biết kết quả làm khảo sát của một người. Có vẻ không có vấn đề các dòng có ý nghĩa khác nhau.

# %% [markdown]
# ### Dữ liệu có các dòng bị lặp không? (0.25đ)

# %% [markdown]
# Kế đến, bạn tính số dòng có index (id của người làm khảo sát) bị lặp và lưu vào biến `num_duplicated_rows`. Trong nhóm các dòng có index giống nhau thì dòng đầu tiên không tính là bị lặp.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
num_duplicated_rows = survey_df.index.duplicated().sum()
print(num_duplicated_rows)
# Out:
# 0

# %%
# TEST
assert num_duplicated_rows == 0

# %% [markdown]
# ### Mỗi cột có ý nghĩa gì? (0.25đ)

# %% [markdown]
# Để xem ý nghĩa của mỗi cột thì:
# - Trước tiên, bạn cần đọc file "survey_results_schema-short.csv" vào DataFrame `col_meaning_df`; bạn cũng cần cho cột "Column" làm cột index.
# - Sau đó, bạn chỉ cần hiển thị DataFrame `col_meaning_df` ra để xem (vụ này khó nên ở dưới mình đã làm cho bạn ở cell có dòng "# TEST" 😉). Tuy nhiên, bạn sẽ thấy ở cột "QuestionText": các chuỗi mô tả bị cắt do quá dài. Do đó, trước khi hiển thị DataFrame `col_meaning_df`, bạn cũng cần chỉnh sao đó để các chuỗi mô tả không bị cắt (vụ này bạn tự search Google, gợi ý: bạn sẽ dùng đến câu lệnh `pd.set_option`).

# %%
# YOUR CODE HERE
#raise NotImplementedError()
pd.set_option('display.max_colwidth', None) #show full text not cut
col_meaning_df = pd.read_csv('survey_results_schema-short.csv', index_col='Column')

# %%
# TEST
col_meaning_df
# Out:
#                                                                                                                                                                                                                                                                                                     QuestionText
# Column
# Respondent                                                                                                                                                                                                                                Randomized respondent ID number (not in order of survey response time)
# MainBranch                                                                                                                                                                                      Which of the following options best describes you today? Here, by "developer" we mean "someone who writes code."
# Hobbyist                                                                                                                                                                                                                                                                                 Do you code as a hobby?
# Age                                                                                                                                                                                                                 What is your age (in years)? If you prefer not to answer, you may leave this question blank.
# ConvertedComp                                                                                                                                                                    Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.
# Country                                                                                                                                                                                                                                                                                       Where do you live?
# DevType                                                                                                                                                                                                                                       Which of the following describe you? Please select all that apply.
# EdLevel                                                                                                                                                                                                       Which of the following best describes the highest level of formal education that you’ve completed?
# Employment                                                                                                                                                                                                                                 Which of the following best describes your current employment status?
# Ethnicity                                                                                                                                                              Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
# Gender                                                                                                                                                                 Which of the following describe you, if any? Please check all that apply. If you prefer not to answer, you may leave this question blank.
# JobFactors                                                                                                                                 Imagine that you are deciding between two job offers with the same compensation, benefits, and location. Of the following factors, which 3 are MOST important to you?
# JobSat                                                                                                                                                                                 How satisfied are you with your current job? (If you work multiple jobs, answer for the one you spend the most hours on.)
# LanguageDesireNextYear        Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# LanguageWorkedWith            Which programming, scripting, and markup languages have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the language and want to continue to do so, please check both boxes in that row.)
# MiscTechDesireNextYear             Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# MiscTechWorkedWith                 Which other frameworks, libraries, and tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)
# NEWCollabToolsDesireNextYear                                    Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
# NEWCollabToolsWorkedWith                                        Which collaboration tools have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you worked with the tool and want to continue to do so, please check both boxes in that row.)
# NEWEdImpt                                                                                                                                                                                                  How important is a formal education, such as a university degree in computer science, to your career?
# NEWLearn                                                                                                                                                                                                                                                How frequently do you learn a new language or framework?
# NEWOvertime                                                                                                                                                                                                                    How often do you work overtime or beyond the formal time expectation of your job?
# NEWStuck                                                                                                                                                                                                                                  What do you do when you get stuck on a problem? Select all that apply.
# OpSys                                                                                                                                                                                                                                                    What is the primary operating system in which you work?
# PlatformDesireNextYear                                           Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
# PlatformWorkedWith                                               Which platforms have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the platform and want to continue to do so, please check both boxes in that row.)
# WorkWeekHrs                                                                                                                                                                                                             On average, how many hours per week do you work? Please enter a whole number in the box.
# YearsCode                                                                                                                                                                                                                                 Including any education, how many years have you been coding in total?
# YearsCodePro                                                                                                                                                                                                     NOT including education, how many years have you coded professionally (as a part of your work)?

# %% [markdown]
# Trước khi đi tiếp, bạn nên đọc kết quả hiển thị ở trên và đảm bảo là bạn đã hiểu ý nghĩa của các cột. Để hiểu ý nghĩa của cột, có thể bạn sẽ cần xem thêm các giá trị của cột bên DataFrame `survey_df`.

# %% [markdown]
# ### Mỗi cột hiện đang có kiểu dữ liệu gì? Có cột nào có kiểu dữ liệu chưa phù hợp để có thể xử lý tiếp không? (0.25đ)

# %% [markdown]
# Kế đến, bạn tính kiểu dữ liệu (dtype) của mỗi cột trong DataFrame `survey_df` và lưu kết quả vào Series `dtypes` (Series này có index là tên cột).

# %%
# YOUR CODE HERE
#raise NotImplementedError()
dtypes = survey_df.dtypes
dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# ConvertedComp                   float64
# Country                          object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# MiscTechWorkedWith               object
# NEWCollabToolsDesireNextYear     object
# NEWCollabToolsWorkedWith         object
# NEWEdImpt                        object
# NEWLearn                         object
# NEWOvertime                      object
# NEWStuck                         object
# OpSys                            object
# PlatformDesireNextYear           object
# PlatformWorkedWith               object
# WorkWeekHrs                     float64
# YearsCode                        object
# YearsCodePro                     object
# dtype: object

# %%
# TEST
float_cols = set(dtypes[(dtypes==np.float32) | (dtypes==np.float64)].index)
assert float_cols == {'Age', 'ConvertedComp', 'WorkWeekHrs'}
object_cols = set(dtypes[dtypes == object].index)
assert len(object_cols) == 25

# %% [markdown]
# Như bạn có thể thấy, cột "YearsCode" và "YearsCodePro" nên có kiểu dữ liệu số, nhưng hiện giờ đang có kiểu dữ liệu object. Ta hãy thử xem thêm về các giá trị 2 cột này.

# %%
survey_df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
survey_df['YearsCodePro'].unique()
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %% [markdown]
# Ta nên đưa 2 cột này về dạng số để có thể tiếp tục khám phá (tính min, median, max, ...).

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Bạn sẽ thực hiện tiền xử lý để chuyển 2 cột "YearsCode" và "YearsCodePro" về dạng số (float). Trong đó: "Less than 1 year" $\to$ 0, "More than 50 years" $\to$ 51. Sau khi chuyển thì `survey_df.dtypes` sẽ thay đổi.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
list_convert = {"Less than 1 year":"0", "More than 50 years":"51"}
#survey_df['YearsCode'] = survey_df['YearsCode'].map(list_convert).astype(float)
#survey_df['YearsCodePro'] = survey_df['YearsCodePro'].map(list_convert).astype(float)
#use lambda to avoid replacing other value not in list_convert
survey_df['YearsCode'] = survey_df['YearsCode'].apply(lambda ele: list_convert[ele] if ele in list_convert else ele).astype(float)
survey_df['YearsCodePro'] = survey_df['YearsCodePro'].apply(lambda ele: list_convert[ele] if ele in list_convert else ele).astype(float)
survey_df.dtypes
# Out:
# MainBranch                       object
# Hobbyist                         object
# Age                             float64
# ConvertedComp                   float64
# Country                          object
# DevType                          object
# EdLevel                          object
# Employment                       object
# Ethnicity                        object
# Gender                           object
# JobFactors                       object
# JobSat                           object
# LanguageDesireNextYear           object
# LanguageWorkedWith               object
# MiscTechDesireNextYear           object
# MiscTechWorkedWith               object
# NEWCollabToolsDesireNextYear     object
# NEWCollabToolsWorkedWith         object
# NEWEdImpt                        object
# NEWLearn                         object
# NEWOvertime                      object
# NEWStuck                         object
# OpSys                            object
# PlatformDesireNextYear           object
# PlatformWorkedWith               object
# WorkWeekHrs                     float64
# YearsCode                       float64
# YearsCodePro                    float64
# dtype: object

# %%
# TEST
assert survey_df['YearsCode'].dtype in [np.float32, np.float64]
assert survey_df['YearsCodePro'].dtype in [np.float32, np.float64]

# %% [markdown]
# ---

# %% [markdown]
# ## Quay lại bước khám phá dữ liệu

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu dạng số, các giá trị được phân bố như thế nào? (1đ)
#
# (Trong đó: phần tính các mô tả của mỗi cột chiếm 0.5đ, phần tính số lượng giá trị không hợp lệ của mỗi cột chiếm 0.5đ)

# %% [markdown]
# Với các cột có kiểu dữ liệu số, bạn sẽ tính:
# - Tỉ lệ % (từ 0 đến 100) các giá trị thiếu
# - Giá trị min
# - Giá trị lower quartile (phân vị 25)
# - Giá trị median (phân vị 50)
# - Giá trị upper quartile (phân vị 75)
# - Giá trị max
#
# Bạn sẽ lưu kết quả vào DataFrame `nume_col_info_df`, trong đó:
# - Tên của các cột là tên của các cột số trong `survey_df`
# - Tên của các dòng là: "missing_percentage", "min", "lower_quartile", "median", "upper_quartile", "max"
#
# Để dễ nhìn, tất cả các giá trị bạn đều làm tròn với 1 chữ số thập phân bằng phương thức `.round(1)`.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
col_only_numeric = survey_df.select_dtypes(include=['float32', 'float64']) #select just column float 
nume_col_info_df = col_only_numeric.describe().transpose().drop(columns=['mean', 'std']) #remove 2 rows mean and std
nume_col_info_df['count'] = survey_df.isnull().sum() * 100.0 / len(survey_df) #calc % missing
my_dict_info = {'count': 'missing_percentage', '25%': 'lower_quartile', '50%': 'median', '75%': 'upper_quartile'} 
nume_col_info_df = nume_col_info_df.rename(columns=my_dict_info).round(1).transpose() #rename and round
nume_col_info_df
# Out:
#                       Age  ConvertedComp  WorkWeekHrs  YearsCode  YearsCodePro
# missing_percentage   29.5           46.1         36.2       10.5          28.1
# min                   1.0            0.0          1.0        0.0           0.0
# lower_quartile       24.0        24648.0         40.0        6.0           3.0
# median               29.0        54049.0         40.0       10.0           6.0
# upper_quartile       35.0        95000.0         44.0       17.0          12.0
# max                 279.0      2000000.0        475.0       51.0          51.0

# %%
# TEST
assert nume_col_info_df.shape == (6, 5)
data = nume_col_info_df.loc[['missing_percentage', 'min', 'lower_quartile', 'median', 'upper_quartile', 'max'],
                           ['Age', 'ConvertedComp', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro']].values
correct_data = np.array([[     29.5,      46.1,      36.2,      10.5,      28.1],
                         [      1. ,       0. ,       1. ,       0. ,       0. ],
                         [     24. ,   24648. ,      40. ,       6. ,       3. ],
                         [     29. ,   54049. ,      40. ,      10. ,       6. ],
                         [     35. ,   95000. ,      44. ,      17. ,      12. ],
                         [    279. , 2000000. ,     475. ,      51. ,      51. ]])
assert np.array_equal(data, correct_data)

# %% [markdown]
# **Có giá trị không hợp lệ trong mỗi cột không? (không xét giá trị thiếu)**
# - Cột "Age": bạn hãy tính số lượng giá trị không hợp lệ của cột "Age" (< giá trị tương ứng trong cột "YearsCode" HOẶC < giá trị tương ứng trong cột "YearsCodePro") và lưu kết quả vào biến `num_invalid_Age_vals`.
# - Cột "WorkWeekHrs" (số giờ làm việc trung bình một tuần): ta thấy max là 475 giờ! Trong khi đó, 7 ngày * 24 giờ = 168 giờ! Bạn hãy tính số lượng giá trị không hợp lệ của cột "WorkWeekHrs" (> 24 * 7) và lưu kết quả vào biến `num_invalid_WorkWeekHrs`.
# - Cột "YearsCode": bạn hãy tính số lượng giá trị không hợp lệ của cột "YearsCode" (< giá trị tương ứng trong cột "YearsCodePro" HOẶC > giá trị tương ứng trong cột "Age") và lưu kết quả vào biến `num_invalid_YearsCode`.
# - Cột "YearsCodePro": bạn hãy tính số lượng giá trị không hợp lệ của cột "YearsCodePro" (> giá trị tương ứng trong cột "YearsCode" HOẶC > giá trị tương ứng trong cột "Age") và lưu kết quả vào biến `num_invalid_YearsCodePro`.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
#use logic OR to return all rows where A = ... or B = ...
not_valid_age = (survey_df['Age'] < survey_df['YearsCode']) | (survey_df['Age'] < survey_df['YearsCodePro'])
num_invalid_Age_vals = len(survey_df[not_valid_age])
not_valid_workweekhrs = survey_df['WorkWeekHrs'] > 24*7
num_invalid_WorkWeekHrs_vals = len(survey_df[not_valid_workweekhrs])
not_valid_yearscode = (survey_df['YearsCode'] < survey_df['YearsCodePro']) | (survey_df['YearsCode'] > survey_df['Age'])
num_invalid_YearsCode_vals = len(survey_df[not_valid_yearscode])
not_valid_yearscodepro = (survey_df['YearsCodePro'] > survey_df['YearsCode']) | (survey_df['YearsCodePro'] > survey_df['Age'])
num_invalid_YearsCodePro_vals = len(survey_df[not_valid_yearscodepro])
print(num_invalid_WorkWeekHrs_vals)
print(num_invalid_Age_vals)
print(num_invalid_YearsCode_vals)
print(num_invalid_YearsCodePro_vals)
# Out:
# 62
# 16
# 499
# 486

# %%
# TEST
assert num_invalid_WorkWeekHrs_vals == 62
assert num_invalid_Age_vals == 16
assert num_invalid_YearsCode_vals == 499
assert num_invalid_YearsCodePro_vals == 486

# %% [markdown]
# Do số lượng các giá trị không hợp lệ cũng khá ít nên ta có thể tiền xử lý bằng cách xóa các dòng chứa các giá trị không hợp lệ.

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý (0.5đ)

# %% [markdown]
# Bạn sẽ thực hiện tiền xử lý để xóa đi các dòng của DataFrame `survey_df` mà chứa ít nhất là một giá trị không hợp lệ. Sau khi tiền xử lý thì `survey_df` sẽ thay đổi.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
#use logic not to inverse
#survey_df = survey_df[~not_valid_age]
#survey_df = survey_df[~not_valid_workweekhrs]
#survey_df = survey_df[~not_valid_yearscode]
#survey_df = survey_df[~not_valid_yearscodepro]
#convert all above to boolean to avoid warning boolean series key will be reindexed to match dataFrame index
survey_df = survey_df[~(not_valid_age | not_valid_workweekhrs | not_valid_yearscode | not_valid_yearscodepro)]
print(len(survey_df))
# Out:
# 63900

# %%
# TEST
assert len(survey_df) == 63900

# %% [markdown]
# ---

# %% [markdown]
# ## Quay lại bước khám phá dữ liệu

# %% [markdown]
# ### Với mỗi cột có kiểu dữ liệu không phải dạng số, các giá trị được phân bố như thế nào? (1đ)

# %% [markdown]
# Với các cột có kiểu dữ liệu không phải số, bạn sẽ tính:
# - Tỉ lệ % (từ 0 đến 100) các giá trị thiếu
# - Số lượng các giá trị (các giá trị ở đây là các giá trị khác nhau và ta không xét giá trị thiếu): với cột mà ứng với câu hỏi dạng multichoice (ví dụ, cột "DevType"), mỗi giá trị có thể chứa nhiều choice (các choice được phân tách bởi dấu chấm phẩy), và việc đếm trực tiếp các giá trị không có nhiều ý nghĩa lắm vì số lượng tổ hợp các choice là khá nhiều; một cách khác tốt hơn mà bạn sẽ làm là đếm số lượng các choice
# - Tỉ lệ % (từ 0 đến 100) của mỗi giá trị được sort theo tỉ lệ % giảm dần (ta không xét giá trị thiếu, tỉ lệ là tỉ lệ so với số lượng các giá trị không thiếu): bạn dùng dictionary để lưu, key là giá trị, value là tỉ lệ %; với cột mà ứng với câu hỏi dạng multichoice, cách làm tương tự như ở trên
#
# Bạn sẽ lưu kết quả vào DataFrame `cate_col_info_df`, trong đó:
# - Tên của các cột là tên của các cột không phải số trong `survey_df`
# - Tên của các dòng là: "missing_percentage", "num_values", "value_percentages"
#
# Để dễ nhìn, tất cả các giá trị bạn đều làm tròn với 1 chữ số thập phân bằng phương thức `.round(1)`.
#
# Gợi ý: có thể bạn sẽ muốn dùng [phương thức `explode`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.explode.html).

# %%
# Các cột ứng với câu hỏi khảo sát multichoice
multichoice_cols = ['DevType', 'Gender', 'JobFactors', 
                    'LanguageWorkedWith', 'LanguageDesireNextYear', 
                    'MiscTechWorkedWith', 'MiscTechDesireNextYear', 
                    'NEWCollabToolsWorkedWith', 'NEWCollabToolsDesireNextYear', 
                    'PlatformWorkedWith', 'PlatformDesireNextYear', 
                    'NEWStuck']

# %%
pd.set_option('display.max_colwidth', 100) # Để dễ nhìn
pd.set_option('display.max_columns', None) # Để dễ nhìn
# YOUR CODE HERE
#raise NotImplementedError()
exclude_numeric = survey_df.select_dtypes(exclude=['float32', 'float64']) #exclude numeric first
missing_percentage = exclude_numeric.isnull().sum() * 100.0 / len(survey_df) #calc % missing
missing_percentage = pd.DataFrame(missing_percentage.round(1)) 
cate_col_info_df = missing_percentage.rename(columns={0:"missing_percentage"}) #rename column
cate_col_info_df
# Out:
#                               missing_percentage
# MainBranch                                   0.5
# Hobbyist                                     0.1
# Country                                      0.6
# DevType                                     23.6
# EdLevel                                     11.0
# Employment                                   0.9
# Ethnicity                                   28.6
# Gender                                      21.5
# JobFactors                                  23.4
# JobSat                                      30.1
# LanguageDesireNextYear                      16.0
# LanguageWorkedWith                          11.0
# MiscTechDesireNextYear                      34.3
# MiscTechWorkedWith                          37.5
# NEWCollabToolsDesireNextYear                26.6
# NEWCollabToolsWorkedWith                    18.0
# NEWEdImpt                                   25.0
# NEWLearn                                    12.9
# NEWOvertime                                 33.1
# NEWStuck                                    14.7
# OpSys                                       12.8
# PlatformDesireNextYear                      21.5
# PlatformWorkedWith                          16.5

# %%
get_name_cate_col_info_df = cate_col_info_df.transpose().columns
get_name_cate_col_info_df
# Out:
# Index(['MainBranch', 'Hobbyist', 'Country', 'DevType', 'EdLevel', 'Employment',
#        'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'LanguageDesireNextYear',
#        'LanguageWorkedWith', 'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWEdImpt',
#        'NEWLearn', 'NEWOvertime', 'NEWStuck', 'OpSys',
#        'PlatformDesireNextYear', 'PlatformWorkedWith'],
#       dtype='object')

# %%
#create 2 dict for num_values and value_percentages
num_values = {}
value_percentages = {}
for elem in get_name_cate_col_info_df:
    #first process column with multi-choice
    if elem in multichoice_cols:
        exclude_numeric[elem] = exclude_numeric[elem].str.split(';') #split by delimeter for columns not numeric
        col_explode = exclude_numeric[elem].explode() #explode after spliting
        count_value_after_explode = col_explode.value_counts() #count after exploding
        num_values[elem] = len(count_value_after_explode.index.values) #calculate num_values
        #calculate value_percentages
        value_percentages[elem] = {} #init empty dict for col with multi chocie
        for i in count_value_after_explode.index.values:
            #ex: value_percentages[devType][Developer, back-end] = count_value_after_explode[Developer, backend]*100.0/sum col after exploding not null...
            value_percentages[elem][i] = (count_value_after_explode[i]*100.0/(~col_explode.isnull()).sum()).round(1) 
    #second process column without multi-choice
    else:
        # calculate num_values for others
        count_value_after_explode1 = exclude_numeric[elem].value_counts() #count without explode with no multi chocie
        num_values[elem] = len(count_value_after_explode1.index.values)
        # calculate value_ratios for others
        value_percentages[elem] = {} #init empty dict for col without multi chocie
        for i in count_value_after_explode1.index.values:
            #change to sum col without exploding not null
            value_percentages[elem][i] = (count_value_after_explode1[i]*100.0/(~exclude_numeric[elem].isnull()).sum()).round(1)
#num_values
#value_percentages
# Out:
# c:\program files\python36\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
#add values of num_values to list l1
l1 = []
for key, value in num_values.items():
    l1.append(value)
print(l1)
# Out:
# [5, 2, 183, 23, 9, 7, 204, 3, 11, 5, 25, 25, 19, 19, 11, 11, 5, 4, 5, 9, 4, 16, 16]

# %%
#add values of num_values to list l2
l2 = []
for key1, value1 in value_percentages.items():
    l2.append(tuple((key1, value1)))
l2
# Out:
# [('MainBranch',
#   {'I am a developer by profession': 73.5,
#    'I am a student who is learning to code': 12.5,
#    'I am not primarily a developer, but I write code sometimes as part of my work': 8.5,
#    'I code primarily as a hobby': 3.6,
#    'I used to be a developer by profession, but no longer am': 1.8}),
#  ('Hobbyist', {'Yes': 78.2, 'No': 21.8}),
#  ('Country',
#   {'United States': 19.5,
#    'India': 13.0,
#    'United Kingdom': 6.1,
#    'Germany': 6.1,
#    'Canada': 3.4,
#    'France': 3.0,
#    'Brazil': 2.8,
#    'Netherlands': 2.1,
#    'Poland': 2.0,
#    'Australia': 1.9,
#    'Spain': 1.8,
#    'Italy': 1.7,
#    'Russian Federation': 1.7,
#    'Sweden': 1.4,
#    'Pakistan': 1.3,
#    'Turkey': 1.2,
#    'Israel': 1.0,
#    'Switzerland': 1.0,
#    'Romania': 0.9,
#    'Bangladesh': 0.9,
#    'Nigeria': 0.9,
#    'Ukraine': 0.8,
#    'Mexico': 0.8,
#    'Austria': 0.8,
#    'Czech Republic': 0.8,
#    'South Africa': 0.8,
#    'Indonesia': 0.8,
#    'Iran': 0.8,
#    'Belgium': 0.7,
#    'Ireland': 0.7,
#    'Philippines': 0.6,
#    'Denmark': 0.6,
#    'Argentina': 0.6,
#    'Greece': 0.6,
#    'Portugal': 0.6,
#    'Hungary': 0.6,
#    'Norway': 0.6,
#    'China': 0.6,
#    'New Zealand': 0.6,
#    'Viet Nam': 0.5,
#    'Finland': 0.5,
#    'Bulgaria': 0.5,
#    'Serbia': 0.5,
#    'Japan': 0.5,
#    'Sri Lanka': 0.5,
#    'Colombia': 0.4,
#    'Egypt': 0.4,
#    'Kenya': 0.4,
#    'Nepal': 0.4,
#    'Malaysia': 0.4,
#    'Singapore': 0.4,
#    'South Korea': 0.3,
#    'Slovakia': 0.3,
#    'Croatia': 0.3,
#    'Chile': 0.3,
#    'Morocco': 0.3,
#    'Lithuania': 0.3,
#    'Taiwan': 0.2,
#    'Slovenia': 0.2,
#    'Thailand': 0.2,
#    'Estonia': 0.2,
#    'Belarus': 0.2,
#    'Tunisia': 0.2,
#    'United Arab Emirates': 0.2,
#    'Latvia': 0.2,
#    'Hong Kong (S.A.R.)': 0.2,
#    'Ghana': 0.2,
#    'Uruguay': 0.2,
#    'Peru': 0.2,
#    'Bosnia and Herzegovina': 0.2,
#    'Algeria': 0.1,
#    'Saudi Arabia': 0.1,
#    'Republic of Korea': 0.1,
#    'Afghanistan': 0.1,
#    'Uganda': 0.1,
#    'Costa Rica': 0.1,
#    'Dominican Republic': 0.1,
#    'Venezuela, Bolivarian Republic of...': 0.1,
#    'Lebanon': 0.1,
#    'Georgia': 0.1,
#    'Armenia': 0.1,
#    'Kazakhstan': 0.1,
#    'Ethiopia': 0.1,
#    'Jordan': 0.1,
#    'Iceland': 0.1,
#    'Albania': 0.1,
#    'Azerbaijan': 0.1,
#    'Republic of Moldova': 0.1,
#    'Cameroon': 0.1,
#    'Cyprus': 0.1,
#    'Myanmar': 0.1,
#    'Malta': 0.1,
#    'Ecuador': 0.1,
#    'Guatemala': 0.1,
#    'Luxembourg': 0.1,
#    'Iraq': 0.1,
#    'Uzbekistan': 0.1,
#    'The former Yugoslav Republic of Macedonia': 0.1,
#    'Bolivia': 0.1,
#    'Nicaragua': 0.1,
#    'Sudan': 0.1,
#    'Kosovo': 0.1,
#    'Rwanda': 0.0,
#    'Zimbabwe': 0.0,
#    'United Republic of Tanzania': 0.0,
#    'Nomadic': 0.0,
#    'Cambodia': 0.0,
#    'Paraguay': 0.0,
#    'El Salvador': 0.0,
#    'Senegal': 0.0,
#    'Panama': 0.0,
#    'Cuba': 0.0,
#    'Honduras': 0.0,
#    'Zambia': 0.0,
#    'Madagascar': 0.0,
#    'Qatar': 0.0,
#    'Mauritius': 0.0,
#    'Somalia': 0.0,
#    'Kuwait': 0.0,
#    "Côte d'Ivoire": 0.0,
#    'Kyrgyzstan': 0.0,
#    'Jamaica': 0.0,
#    'Montenegro': 0.0,
#    'Syrian Arab Republic': 0.0,
#    'Mongolia': 0.0,
#    'Andorra': 0.0,
#    'Oman': 0.0,
#    'Maldives': 0.0,
#    'Togo': 0.0,
#    'Bahrain': 0.0,
#    'Angola': 0.0,
#    'Benin': 0.0,
#    'Malawi': 0.0,
#    'Isle of Man': 0.0,
#    'Congo, Republic of the...': 0.0,
#    'Botswana': 0.0,
#    'Namibia': 0.0,
#    'Libyan Arab Jamahiriya': 0.0,
#    'Democratic Republic of the Congo': 0.0,
#    'Bhutan': 0.0,
#    'Mozambique': 0.0,
#    'Yemen': 0.0,
#    'Trinidad and Tobago': 0.0,
#    'Swaziland': 0.0,
#    "Lao People's Democratic Republic": 0.0,
#    'Sierra Leone': 0.0,
#    'Burkina Faso': 0.0,
#    'Guyana': 0.0,
#    'Guinea': 0.0,
#    'Niger': 0.0,
#    'Haiti': 0.0,
#    'Gambia': 0.0,
#    'Barbados': 0.0,
#    'Mauritania': 0.0,
#    'Tajikistan': 0.0,
#    'Bahamas': 0.0,
#    'Brunei Darussalam': 0.0,
#    'Turkmenistan': 0.0,
#    'Eritrea': 0.0,
#    'Belize': 0.0,
#    'Saint Vincent and the Grenadines': 0.0,
#    'Cape Verde': 0.0,
#    'Burundi': 0.0,
#    'Monaco': 0.0,
#    'San Marino': 0.0,
#    'Papua New Guinea': 0.0,
#    'Antigua and Barbuda': 0.0,
#    'Solomon Islands': 0.0,
#    'Djibouti': 0.0,
#    'Timor-Leste': 0.0,
#    'Gabon': 0.0,
#    'North Korea': 0.0,
#    'Micronesia, Federated States of...': 0.0,
#    'Fiji': 0.0,
#    'Lesotho': 0.0,
#    'Nauru': 0.0,
#    'Chad': 0.0,
#    'Marshall Islands': 0.0,
#    'Mali': 0.0,
#    'Kiribati': 0.0,
#    'Grenada': 0.0,
#    'Liechtenstein': 0.0,
#    'Saint Lucia': 0.0}),
#  ('DevType',
#   {'Developer, back-end': 17.4,
#    'Developer, full-stack': 17.3,
#    'Developer, front-end': 11.7,
#    'Developer, desktop or enterprise applications': 7.5,
#    'Developer, mobile': 6.0,
#    'DevOps specialist': 3.8,
#    'Database administrator': 3.6,
#    'Designer': 3.4,
#    'System administrator': 3.3,
#    'Developer, embedded applications or devices': 3.0,
#    'Data or business analyst': 2.5,
#    'Data scientist or machine learning specialist': 2.5,
#    'Developer, QA or test': 2.5,
#    'Engineer, data': 2.4,
#    'Academic researcher': 2.2,
#    'Educator': 1.9,
#    'Developer, game or graphics': 1.8,
#    'Engineering manager': 1.7,
#    'Product manager': 1.6,
#    'Scientist': 1.3,
#    'Engineer, site reliability': 1.2,
#    'Senior executive/VP': 0.8,
#    'Marketing or sales professional': 0.4}),
#  ('EdLevel',
#   {'Bachelor’s degree (B.A., B.S., B.Eng., etc.)': 46.3,
#    'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)': 22.8,
#    'Some college/university study without earning a degree': 12.6,
#    'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)': 8.3,
#    'Associate degree (A.A., A.S., etc.)': 3.2,
#    'Other doctoral degree (Ph.D., Ed.D., etc.)': 2.9,
#    'Primary/elementary school': 1.6,
#    'Professional degree (JD, MD, etc.)': 1.4,
#    'I never completed any formal education': 0.8}),
#  ('Employment',
#   {'Employed full-time': 70.8,
#    'Student': 12.3,
#    'Independent contractor, freelancer, or self-employed': 8.9,
#    'Not employed, but looking for work': 3.7,
#    'Employed part-time': 3.5,
#    'Not employed, and not looking for work': 0.5,
#    'Retired': 0.4}),
#  ('Ethnicity',
#   {'White or of European descent': 64.0,
#    'South Asian': 9.7,
#    'Hispanic or Latino/a/x': 4.9,
#    'Black or of African descent': 3.7,
#    'Southeast Asian': 3.6,
#    'East Asian': 3.6,
#    'Middle Eastern': 3.5,
#    'Hispanic or Latino/a/x;White or of European descent': 1.7,
#    'Middle Eastern;White or of European descent': 0.8,
#    'Multiracial': 0.6,
#    'Biracial': 0.3,
#    'White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.2,
#    'South Asian;Southeast Asian': 0.2,
#    'East Asian;Southeast Asian': 0.2,
#    'White or of European descent;Multiracial': 0.1,
#    'East Asian;White or of European descent': 0.1,
#    'Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.1,
#    'Hispanic or Latino/a/x;White or of European descent;Multiracial': 0.1,
#    'Black or of African descent;White or of European descent;Biracial': 0.1,
#    'Hispanic or Latino/a/x;Multiracial': 0.1,
#    'East Asian;White or of European descent;Biracial': 0.1,
#    'East Asian;South Asian': 0.1,
#    'Hispanic or Latino/a/x;White or of European descent;Biracial': 0.1,
#    'Black or of African descent;Hispanic or Latino/a/x': 0.1,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.1,
#    'Black or of African descent;White or of European descent': 0.1,
#    'White or of European descent;Southeast Asian': 0.1,
#    'White or of European descent;Biracial': 0.1,
#    'Black or of African descent;Middle Eastern': 0.1,
#    'Hispanic or Latino/a/x;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.1,
#    'Middle Eastern;White or of European descent;Multiracial': 0.1,
#    'East Asian;Middle Eastern': 0.0,
#    'White or of European descent;Biracial;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;Biracial': 0.0,
#    'East Asian;South Asian;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern': 0.0,
#    'Middle Eastern;White or of European descent;Biracial': 0.0,
#    'Black or of African descent;Biracial': 0.0,
#    'White or of European descent;Multiracial;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;Multiracial': 0.0,
#    'Middle Eastern;South Asian': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;Multiracial': 0.0,
#    'Middle Eastern;Multiracial': 0.0,
#    'Black or of African descent;White or of European descent;Multiracial': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'White or of European descent;South Asian': 0.0,
#    'White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;White or of European descent': 0.0,
#    'East Asian;Biracial': 0.0,
#    'East Asian;White or of European descent;Biracial;Multiracial': 0.0,
#    'White or of European descent;South Asian;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;Biracial;Multiracial': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;Biracial': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;White or of European descent': 0.0,
#    'East Asian;Hispanic or Latino/a/x': 0.0,
#    'Middle Eastern;Biracial': 0.0,
#    'White or of European descent;Biracial;South Asian': 0.0,
#    'Black or of African descent;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Multiracial;Southeast Asian': 0.0,
#    'Biracial;Multiracial': 0.0,
#    'Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;Southeast Asian': 0.0,
#    'Black or of African descent;South Asian': 0.0,
#    'Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Southeast Asian': 0.0,
#    'Middle Eastern;Southeast Asian': 0.0,
#    'East Asian;Hispanic or Latino/a/x;White or of European descent': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'Black or of African descent;Middle Eastern;White or of European descent': 0.0,
#    'East Asian;Multiracial': 0.0,
#    'White or of European descent;Biracial;Multiracial': 0.0,
#    'Black or of African descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'South Asian;Multiracial': 0.0,
#    'East Asian;White or of European descent;Southeast Asian': 0.0,
#    'Black or of African descent;White or of European descent;South Asian;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Southeast Asian': 0.0,
#    'Black or of African descent;White or of European descent;Biracial;Multiracial': 0.0,
#    'Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'East Asian;Middle Eastern;White or of European descent': 0.0,
#    'Biracial;Southeast Asian': 0.0,
#    'White or of European descent;Biracial;Multiracial;Southeast Asian': 0.0,
#    'East Asian;Hispanic or Latino/a/x;White or of European descent;Multiracial': 0.0,
#    'Black or of African descent;Middle Eastern;White or of European descent;Biracial': 0.0,
#    'East Asian;Middle Eastern;South Asian;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian': 0.0,
#    'Black or of African descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Multiracial': 0.0,
#    'Middle Eastern;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'East Asian;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;White or of European descent;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;Multiracial': 0.0,
#    'Middle Eastern;White or of European descent;Biracial;Multiracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;White or of European descent;Biracial': 0.0,
#    'East Asian;Hispanic or Latino/a/x;Biracial;Multiracial': 0.0,
#    'East Asian;Middle Eastern;White or of European descent;Biracial': 0.0,
#    'White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;South Asian;Multiracial;Southeast Asian': 0.0,
#    'East Asian;Middle Eastern;Multiracial': 0.0,
#    'East Asian;White or of European descent;South Asian;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Biracial;Southeast Asian': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Black or of African descent;Middle Eastern;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Biracial;Multiracial': 0.0,
#    'Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'East Asian;Middle Eastern;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;South Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;White or of European descent;South Asian;Multiracial': 0.0,
#    'East Asian;White or of European descent;Biracial;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;Middle Eastern;Biracial': 0.0,
#    'East Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;South Asian;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;South Asian;Multiracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Southeast Asian': 0.0,
#    'East Asian;Middle Eastern;White or of European descent;South Asian': 0.0,
#    'Black or of African descent;East Asian;Multiracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;White or of European descent;Multiracial': 0.0,
#    'Black or of African descent;East Asian;Middle Eastern;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;White or of European descent;Multiracial;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'East Asian;Hispanic or Latino/a/x;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial;Southeast Asian': 0.0,
#    'White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;Biracial;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Southeast Asian': 0.0,
#    'Black or of African descent;Middle Eastern;White or of European descent;Multiracial': 0.0,
#    'East Asian;Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'East Asian;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial;Southeast Asian': 0.0,
#    'East Asian;Hispanic or Latino/a/x;White or of European descent;Biracial;South Asian;Multiracial;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'East Asian;White or of European descent;South Asian;Southeast Asian': 0.0,
#    'East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;South Asian': 0.0,
#    'Black or of African descent;East Asian;White or of European descent': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'East Asian;Hispanic or Latino/a/x;Multiracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;Biracial;South Asian;Multiracial': 0.0,
#    'East Asian;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Biracial;South Asian': 0.0,
#    'East Asian;Middle Eastern;White or of European descent;South Asian;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Black or of African descent;South Asian;Multiracial': 0.0,
#    'Black or of African descent;White or of European descent;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;White or of European descent;Southeast Asian': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;South Asian;Multiracial': 0.0,
#    'East Asian;Middle Eastern;South Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent': 0.0,
#    'Middle Eastern;White or of European descent;South Asian': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;Southeast Asian': 0.0,
#    'Middle Eastern;Biracial;South Asian;Multiracial': 0.0,
#    'Middle Eastern;White or of European descent;Biracial;South Asian;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;Biracial': 0.0,
#    'East Asian;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern': 0.0,
#    'White or of European descent;Biracial;South Asian;Multiracial': 0.0,
#    'East Asian;Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Hispanic or Latino/a/x;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Southeast Asian': 0.0,
#    'East Asian;White or of European descent;Biracial;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;South Asian': 0.0,
#    'Black or of African descent;Middle Eastern;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'White or of European descent;Biracial;South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Southeast Asian': 0.0,
#    'East Asian;Middle Eastern;White or of European descent;Biracial;Multiracial': 0.0,
#    'East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;Hispanic or Latino/a/x;White or of European descent;Biracial;Multiracial': 0.0,
#    'Black or of African descent;Middle Eastern;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'East Asian;Biracial;South Asian;Multiracial': 0.0,
#    'Black or of African descent;Biracial;Multiracial': 0.0,
#    'Hispanic or Latino/a/x;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial': 0.0,
#    'Middle Eastern;White or of European descent;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Middle Eastern;South Asian': 0.0,
#    'White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;Middle Eastern;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;White or of European descent;Biracial;South Asian;Multiracial': 0.0,
#    'Black or of African descent;East Asian;Hispanic or Latino/a/x;Middle Eastern;White or of European descent;Biracial;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian)': 0.0,
#    'East Asian;White or of European descent;Multiracial;Southeast Asian': 0.0,
#    'Black or of African descent;Middle Eastern;Biracial;Multiracial': 0.0,
#    'Black or of African descent;Multiracial;Southeast Asian': 0.0,
#    'Hispanic or Latino/a/x;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian': 0.0,
#    'Hispanic or Latino/a/x;White or of European descent;South Asian;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Middle Eastern;White or of European descent;Indigenous (such as Native American, Pacific Islander, or Indigenous Australian);South Asian;Southeast Asian': 0.0,
#    'Black or of African descent;East Asian;Middle Eastern;White or of European descent;Biracial;Multiracial': 0.0}),
#  ('Gender',
#   {'Man': 90.8,
#    'Woman': 7.9,
#    'Non-binary, genderqueer, or gender non-conforming': 1.2}),
#  ('JobFactors',
#   {'Languages, frameworks, and other technologies I’d be working with': 17.5,
#    'Office environment or company culture': 15.2,
#    'Flex time or a flexible schedule': 15.0,
#    'Opportunities for professional development': 14.1,
#    'Remote work options': 11.3,
#    'How widely used or impactful my work output would be': 7.1,
#    'Industry that I’d be working in': 5.2,
#    'Family friendliness': 4.1,
#    'Financial performance or funding status of the company or organization': 4.1,
#    'Specific department or team I’d be working on': 4.0,
#    'Diversity of the company or organization': 2.3}),
#  ('JobSat',
#   {'Very satisfied': 32.4,
#    'Slightly satisfied': 30.9,
#    'Slightly dissatisfied': 15.8,
#    'Neither satisfied nor dissatisfied': 12.8,
#    'Very dissatisfied': 8.2}),
#  ('LanguageDesireNextYear',
#   {'Python': 11.2,
#    'JavaScript': 11.0,
#    'HTML/CSS': 8.7,
#    'SQL': 8.4,
#    'TypeScript': 7.2,
#    'C#': 5.7,
#    'Java': 5.6,
#    'Go': 5.3,
#    'Bash/Shell/PowerShell': 4.9,
#    'Rust': 4.4,
#    'C++': 4.1,
#    'Kotlin': 4.0,
#    'PHP': 3.0,
#    'C': 2.6,
#    'Swift': 2.4,
#    'Dart': 2.0,
#    'R': 1.8,
#    'Ruby': 1.8,
#    'Scala': 1.5,
#    'Haskell': 1.3,
#    'Assembly': 1.0,
#    'Julia': 0.7,
#    'Objective-C': 0.6,
#    'Perl': 0.5,
#    'VBA': 0.4}),
#  ('LanguageWorkedWith',
#   {'JavaScript': 13.5,
#    'HTML/CSS': 12.6,
#    'SQL': 10.9,
#    'Python': 8.8,
#    'Java': 8.0,
#    'Bash/Shell/PowerShell': 6.6,
#    'C#': 6.3,
#    'PHP': 5.2,
#    'TypeScript': 5.1,
#    'C++': 4.8,
#    'C': 4.3,
#    'Go': 1.7,
#    'Kotlin': 1.5,
#    'Ruby': 1.4,
#    'Assembly': 1.2,
#    'VBA': 1.2,
#    'Swift': 1.2,
#    'R': 1.1,
#    'Rust': 1.0,
#    'Objective-C': 0.8,
#    'Dart': 0.8,
#    'Scala': 0.7,
#    'Perl': 0.6,
#    'Haskell': 0.4,
#    'Julia': 0.2}),
#  ('MiscTechDesireNextYear',
#   {'Node.js': 17.0,
#    'TensorFlow': 10.1,
#    '.NET Core': 9.6,
#    'React Native': 8.4,
#    '.NET': 6.9,
#    'Flutter': 6.5,
#    'Unity 3D': 6.1,
#    'Pandas': 5.6,
#    'Torch/PyTorch': 4.2,
#    'Unreal Engine': 3.5,
#    'Teraform': 3.4,
#    'Apache Spark': 3.3,
#    'Hadoop': 3.3,
#    'Keras': 3.1,
#    'Xamarin': 3.0,
#    'Ansible': 2.9,
#    'Cordova': 1.3,
#    'Puppet': 1.1,
#    'Chef': 0.9}),
#  ('MiscTechWorkedWith',
#   {'Node.js': 23.1,
#    '.NET': 15.7,
#    '.NET Core': 12.0,
#    'Pandas': 7.0,
#    'TensorFlow': 5.2,
#    'React Native': 5.1,
#    'Unity 3D': 4.9,
#    'Ansible': 3.3,
#    'Flutter': 3.2,
#    'Teraform': 2.8,
#    'Keras': 2.8,
#    'Cordova': 2.7,
#    'Xamarin': 2.6,
#    'Apache Spark': 2.3,
#    'Torch/PyTorch': 2.1,
#    'Hadoop': 2.0,
#    'Unreal Engine': 1.5,
#    'Puppet': 1.0,
#    'Chef': 0.8}),
#  ('NEWCollabToolsDesireNextYear',
#   {'Github': 24.7,
#    'Slack': 14.1,
#    'Gitlab': 11.3,
#    'Google Suite (Docs, Meet, etc)': 10.6,
#    'Jira': 10.5,
#    'Trello': 6.5,
#    'Confluence': 6.1,
#    'Microsoft Teams': 5.6,
#    'Microsoft Azure': 5.2,
#    'Stack Overflow for Teams': 4.4,
#    'Facebook Workplace': 1.0}),
#  ('NEWCollabToolsWorkedWith',
#   {'Github': 22.2,
#    'Slack': 14.2,
#    'Jira': 12.8,
#    'Google Suite (Docs, Meet, etc)': 11.1,
#    'Gitlab': 9.9,
#    'Confluence': 8.7,
#    'Trello': 7.9,
#    'Microsoft Teams': 6.9,
#    'Microsoft Azure': 4.0,
#    'Stack Overflow for Teams': 1.5,
#    'Facebook Workplace': 0.8}),
#  ('NEWEdImpt',
#   {'Fairly important': 26.2,
#    'Very important': 24.4,
#    'Somewhat important': 23.5,
#    'Not at all important/not necessary': 16.1,
#    'Critically important': 9.8}),
#  ('NEWLearn',
#   {'Every few months': 37.3,
#    'Once a year': 36.9,
#    'Once every few years': 23.7,
#    'Once a decade': 2.2}),
#  ('NEWOvertime',
#   {'Sometimes: 1-2 days per month but less than weekly': 26.7,
#    'Often: 1-2 days per week or more': 25.5,
#    'Occasionally: 1-2 days per quarter but less than monthly': 21.9,
#    'Rarely: 1-2 days per year or less': 14.9,
#    'Never': 10.9}),
#  ('NEWStuck',
#   {'Visit Stack Overflow': 26.7,
#    'Do other work and come back later': 16.1,
#    'Watch help / tutorial videos': 15.6,
#    'Call a coworker or friend': 14.7,
#    'Go for a walk or other physical activity': 12.8,
#    'Play games': 4.4,
#    'Meditate': 3.5,
#    'Panic': 3.2,
#    'Visit another developer community (please name):': 3.0}),
#  ('OpSys', {'Windows': 48.3, 'Linux-based': 26.6, 'MacOS': 25.1, 'BSD': 0.1}),
#  ('PlatformDesireNextYear',
#   {'Linux': 14.3,
#    'Docker': 12.2,
#    'AWS': 9.6,
#    'Windows': 9.3,
#    'Android': 7.9,
#    'Kubernetes': 7.3,
#    'MacOS': 6.2,
#    'Raspberry Pi': 6.1,
#    'Google Cloud Platform': 6.1,
#    'Microsoft Azure': 5.1,
#    'iOS': 4.9,
#    'Arduino': 3.6,
#    'Heroku': 2.6,
#    'WordPress': 2.0,
#    'Slack Apps and Integrations': 2.0,
#    'IBM Cloud or Watson': 0.9}),
#  ('PlatformWorkedWith',
#   {'Linux': 16.6,
#    'Windows': 16.0,
#    'Docker': 10.6,
#    'AWS': 8.1,
#    'Android': 7.9,
#    'MacOS': 7.2,
#    'Raspberry Pi': 4.5,
#    'Microsoft Azure': 4.4,
#    'WordPress': 4.3,
#    'Google Cloud Platform': 4.2,
#    'iOS': 3.7,
#    'Kubernetes': 3.5,
#    'Heroku': 3.3,
#    'Arduino': 3.2,
#    'Slack Apps and Integrations': 2.2,
#    'IBM Cloud or Watson': 0.5})]

# %%
#merge missing_percentage with num_values
df1 = cate_col_info_df.transpose()
df_tmp1 = pd.DataFrame([l1], columns=get_name_cate_col_info_df, index=['num_values']) #add list l1 to dataframe
df1 = df1.append(df_tmp1)
df1
# Out:
#                     MainBranch  Hobbyist  Country  DevType  EdLevel  \
# missing_percentage         0.5       0.1      0.6     23.6     11.0
# num_values                 5.0       2.0    183.0     23.0      9.0
#
#                     Employment  Ethnicity  Gender  JobFactors  JobSat  \
# missing_percentage         0.9       28.6    21.5        23.4    30.1
# num_values                 7.0      204.0     3.0        11.0     5.0
#
#                     LanguageDesireNextYear  LanguageWorkedWith  \
# missing_percentage                    16.0                11.0
# num_values                            25.0                25.0
#
#                     MiscTechDesireNextYear  MiscTechWorkedWith  \
# missing_percentage                    34.3                37.5
# num_values                            19.0                19.0
#
#                     NEWCollabToolsDesireNextYear  NEWCollabToolsWorkedWith  \
# missing_percentage                          26.6                      18.0
# num_values                                  11.0                      11.0
#
#                     NEWEdImpt  NEWLearn  NEWOvertime  NEWStuck  OpSys  \
# missing_percentage       25.0      12.9         33.1      14.7   12.8
# num_values                5.0       4.0          5.0       9.0    4.0
#
#                     PlatformDesireNextYear  PlatformWorkedWith
# missing_percentage                    21.5                16.5
# num_values                            16.0                16.0

# %%
#add l2 to dataframe and change 0 to value_percentages
df_tmp2 = pd.DataFrame(l2, columns=['0', 'value_percentages'], index=value_percentages.keys()) 
df_tmp2 = df_tmp2.drop(columns=['0']) #drop redundant column 0
df_tmp2 = df_tmp2.transpose()
df1 = df1.append(df_tmp2)
cate_col_info_df = df1
cate_col_info_df
# Out:
#                                                                                                              MainBranch  \
# missing_percentage                                                                                                  0.5
# num_values                                                                                                            5
# value_percentages   {'I am a developer by profession': 73.5, 'I am a student who is learning to code': 12.5, 'I am n...
#
#                                      Hobbyist  \
# missing_percentage                        0.1
# num_values                                  2
# value_percentages   {'Yes': 78.2, 'No': 21.8}
#
#                                                                                                                 Country  \
# missing_percentage                                                                                                  0.6
# num_values                                                                                                          183
# value_percentages   {'United States': 19.5, 'India': 13.0, 'United Kingdom': 6.1, 'Germany': 6.1, 'Canada': 3.4, 'Fr...
#
#                                                                                                                 DevType  \
# missing_percentage                                                                                                 23.6
# num_values                                                                                                           23
# value_percentages   {'Developer, back-end': 17.4, 'Developer, full-stack': 17.3, 'Developer, front-end': 11.7, 'Deve...
#
#                                                                                                                 EdLevel  \
# missing_percentage                                                                                                   11
# num_values                                                                                                            9
# value_percentages   {'Bachelor’s degree (B.A., B.S., B.Eng., etc.)': 46.3, 'Master’s degree (M.A., M.S., M.Eng., MBA...
#
#                                                                                                              Employment  \
# missing_percentage                                                                                                  0.9
# num_values                                                                                                            7
# value_percentages   {'Employed full-time': 70.8, 'Student': 12.3, 'Independent contractor, freelancer, or self-emplo...
#
#                                                                                                               Ethnicity  \
# missing_percentage                                                                                                 28.6
# num_values                                                                                                          204
# value_percentages   {'White or of European descent': 64.0, 'South Asian': 9.7, 'Hispanic or Latino/a/x': 4.9, 'Black...
#
#                                                                                                    Gender  \
# missing_percentage                                                                                   21.5
# num_values                                                                                              3
# value_percentages   {'Man': 90.8, 'Woman': 7.9, 'Non-binary, genderqueer, or gender non-conforming': 1.2}
#
#                                                                                                              JobFactors  \
# missing_percentage                                                                                                 23.4
# num_values                                                                                                           11
# value_percentages   {'Languages, frameworks, and other technologies I’d be working with': 17.5, 'Office environment ...
#
#                                                                                                                  JobSat  \
# missing_percentage                                                                                                 30.1
# num_values                                                                                                            5
# value_percentages   {'Very satisfied': 32.4, 'Slightly satisfied': 30.9, 'Slightly dissatisfied': 15.8, 'Neither sat...
#
#                                                                                                  LanguageDesireNextYear  \
# missing_percentage                                                                                                   16
# num_values                                                                                                           25
# value_percentages   {'Python': 11.2, 'JavaScript': 11.0, 'HTML/CSS': 8.7, 'SQL': 8.4, 'TypeScript': 7.2, 'C#': 5.7, ...
#
#                                                                                                      LanguageWorkedWith  \
# missing_percentage                                                                                                   11
# num_values                                                                                                           25
# value_percentages   {'JavaScript': 13.5, 'HTML/CSS': 12.6, 'SQL': 10.9, 'Python': 8.8, 'Java': 8.0, 'Bash/Shell/Powe...
#
#                                                                                                  MiscTechDesireNextYear  \
# missing_percentage                                                                                                 34.3
# num_values                                                                                                           19
# value_percentages   {'Node.js': 17.0, 'TensorFlow': 10.1, '.NET Core': 9.6, 'React Native': 8.4, '.NET': 6.9, 'Flutt...
#
#                                                                                                      MiscTechWorkedWith  \
# missing_percentage                                                                                                 37.5
# num_values                                                                                                           19
# value_percentages   {'Node.js': 23.1, '.NET': 15.7, '.NET Core': 12.0, 'Pandas': 7.0, 'TensorFlow': 5.2, 'React Nati...
#
#                                                                                            NEWCollabToolsDesireNextYear  \
# missing_percentage                                                                                                 26.6
# num_values                                                                                                           11
# value_percentages   {'Github': 24.7, 'Slack': 14.1, 'Gitlab': 11.3, 'Google Suite (Docs, Meet, etc)': 10.6, 'Jira': ...
#
#                                                                                                NEWCollabToolsWorkedWith  \
# missing_percentage                                                                                                   18
# num_values                                                                                                           11
# value_percentages   {'Github': 22.2, 'Slack': 14.2, 'Jira': 12.8, 'Google Suite (Docs, Meet, etc)': 11.1, 'Gitlab': ...
#
#                                                                                                               NEWEdImpt  \
# missing_percentage                                                                                                   25
# num_values                                                                                                            5
# value_percentages   {'Fairly important': 26.2, 'Very important': 24.4, 'Somewhat important': 23.5, 'Not at all impor...
#
#                                                                                                                NEWLearn  \
# missing_percentage                                                                                                 12.9
# num_values                                                                                                            4
# value_percentages   {'Every few months': 37.3, 'Once a year': 36.9, 'Once every few years': 23.7, 'Once a decade': 2.2}
#
#                                                                                                             NEWOvertime  \
# missing_percentage                                                                                                 33.1
# num_values                                                                                                            5
# value_percentages   {'Sometimes: 1-2 days per month but less than weekly': 26.7, 'Often: 1-2 days per week or more':...
#
#                                                                                                                NEWStuck  \
# missing_percentage                                                                                                 14.7
# num_values                                                                                                            9
# value_percentages   {'Visit Stack Overflow': 26.7, 'Do other work and come back later': 16.1, 'Watch help / tutorial...
#
#                                                                                 OpSys  \
# missing_percentage                                                               12.8
# num_values                                                                          4
# value_percentages   {'Windows': 48.3, 'Linux-based': 26.6, 'MacOS': 25.1, 'BSD': 0.1}
#
#                                                                                                  PlatformDesireNextYear  \
# missing_percentage                                                                                                 21.5
# num_values                                                                                                           16
# value_percentages   {'Linux': 14.3, 'Docker': 12.2, 'AWS': 9.6, 'Windows': 9.3, 'Android': 7.9, 'Kubernetes': 7.3, '...
#
#                                                                                                      PlatformWorkedWith
# missing_percentage                                                                                                 16.5
# num_values                                                                                                           16
# value_percentages   {'Linux': 16.6, 'Windows': 16.0, 'Docker': 10.6, 'AWS': 8.1, 'Android': 7.9, 'MacOS': 7.2, 'Rasp...

# %%
# TEST
c = cate_col_info_df['MainBranch']
assert c.loc['missing_percentage'] == 0.5
assert c.loc['num_values'] == 5
assert c.loc['value_percentages']['I am a developer by profession'] == 73.5

c = cate_col_info_df['Hobbyist']
assert c.loc['missing_percentage'] == 0.1
assert c.loc['num_values'] == 2
assert c.loc['value_percentages']['Yes'] == 78.2

c = cate_col_info_df['DevType']
assert c.loc['missing_percentage'] == 23.6
assert c.loc['num_values'] == 23
assert c.loc['value_percentages']['Academic researcher'] == 2.2

c = cate_col_info_df['PlatformWorkedWith']
assert c.loc['missing_percentage'] == 16.5
assert c.loc['num_values'] == 16
assert c.loc['value_percentages']['Docker'] == 10.6

# %% [markdown]
# ---

# %% [markdown]
# ## Đặt câu hỏi

# %% [markdown]
# Sau khi khám phá dữ liệu, ta đã hiểu hơn về dữ liệu. Bây giờ, ta hãy xem thử có câu hỏi nào có thể được trả lời bằng dữ liệu này.
#
# **Một câu hỏi có thể có là:** Platform nào (Windows, Linux, Docker, AWS, ...) được yêu thích nhất, platform nào được yêu thích nhì, platform nào được yêu thích ba, ...?
#
# Một platform được xem là được yêu thích nếu một người đã dùng platform này (cột "PlatformWorkedWith") và muốn tiếp tục dùng platform trong năm kế (cột "PlatformDesireNextYear").
#
# **Trả lời được câu hỏi này sẽ** phần nào giúp ta định hướng là nên tập trung học platform nào để có thể chuẩn bị cho tương lai (mình nói "phần nào" vì ở đây dữ liệu chỉ giới hạn trong phạm vi những người làm khảo sát của StackOverflow).

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý

# %% [markdown]
# Nếu bạn thấy cần thực hiện thêm thao tác tiền xử lý để chuẩn bị dữ liệu cho bước phân tích thì bạn làm ở đây. Bước này là không bắt buộc.

# %%
# YOUR CODE HERE (OPTION)

# %% [markdown]
# ---

# %% [markdown]
# ## Phân tích dữ liệu (2.25đ)

# %% [markdown]
# Bây giờ, bạn sẽ thực hiện phân tích dữ liệu để trả lời cho câu hỏi ở trên. Cụ thể các bước như sau:
# - Bước 1: tính Series `most_loved_platforms`, trong đó:
#     - Index là tên flatform (ở bước khám phá dữ liệu, bạn đã thấy có tất cả 16 platform)
#     - Data là tỉ lệ % (từ 0 đến 100, được làm tròn với một chữ số thập phân bằng phương thức `round(1)`) được yêu thích (được sort giảm dần)
# - Bước 2: từ Series `most_loved_platforms`, bạn vẽ bar chart:
#     - Bạn cho các bar nằm ngang (cho dễ nhìn)
#     - Bạn đặt tên trục hoành là "Tỉ lệ %"

# %% [markdown]
# Code bước 1.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
is_platform_favourite_df = survey_df[['PlatformWorkedWith', 'PlatformDesireNextYear']]
is_platform_favourite_df.loc[:, 'PlatformWorkedWith'] = is_platform_favourite_df['PlatformWorkedWith'].str.split(';') #first split by delimeter
is_platform_favourite_df = is_platform_favourite_df.explode('PlatformWorkedWith').dropna() #explode and drop column NaN
is_platform_favourite_df.loc[:, 'PlatformDesireNextYear'] = is_platform_favourite_df['PlatformDesireNextYear'].str.split(';') #first split by delimeter
is_platform_favourite_df = is_platform_favourite_df.explode('PlatformDesireNextYear').dropna() #explode and drop column NaN
#set rows PlatformDesireNextYear equal PlatformDesireNextYear to count
duplicate_platform_df = is_platform_favourite_df[is_platform_favourite_df['PlatformDesireNextYear'] == is_platform_favourite_df['PlatformWorkedWith']]
most_loved_platforms = duplicate_platform_df.groupby(['PlatformWorkedWith']).count()
most_loved_platforms = most_loved_platforms.sort_values(by="PlatformDesireNextYear", ascending=False)
most_loved_platforms['PlatformDesireNextYear'] = ((most_loved_platforms['PlatformDesireNextYear']*100.0)/len(duplicate_platform_df)).round(1)
#convert to series for running test
most_loved_platforms = most_loved_platforms.iloc[:, 0]
most_loved_platforms
# Out:
# c:\program files\python36\lib\site-packages\pandas\core\indexing.py:1781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value
# PlatformWorkedWith
# Linux                          20.2
# Windows                        14.6
# Docker                         12.3
# AWS                             8.5
# MacOS                           7.4
# Android                         7.1
# Raspberry Pi                    4.7
# Microsoft Azure                 4.3
# Google Cloud Platform           4.1
# Kubernetes                      3.9
# iOS                             3.5
# Arduino                         2.7
# Heroku                          2.4
# WordPress                       2.2
# Slack Apps and Integrations     1.8
# IBM Cloud or Watson             0.3
# Name: PlatformDesireNextYear, dtype: float64

# %%
# TEST
assert len(most_loved_platforms) == 16
assert most_loved_platforms.loc['Linux'] == 20.2
assert most_loved_platforms.loc['Windows'] == 14.6
assert most_loved_platforms.loc['Docker'] == 12.3

# %% [markdown]
# Code bước 2.

# %%
# YOUR CODE HERE
#raise NotImplementedError()
fig = plt.figure(figsize = (10, 7))
plt.tick_params(labelsize=12)
plt.xlabel("Tỉ lệ %", fontsize=15)
plt.barh(most_loved_platforms.index, most_loved_platforms.values);

# %% [markdown]
# Bạn đã hiểu tại sao mình khuyên bạn là nên tập làm quen dần với các câu lệnh của Linux chưa 😉

# %% [markdown]
# ---

# %% [markdown]
# ## Đặt câu hỏi của bạn (1.5đ)

# %% [markdown]
# Bây giờ, đến lượt bạn phải tự suy nghĩ và đưa ra câu hỏi mà có thể trả lời bằng dữ liệu. Ngoài việc đưa ra câu hỏi, bạn cũng phải giải thích để người đọc thấy nếu trả lời được câu hỏi thì sẽ có lợi ích gì. Bạn nên sáng tạo một xíu, không nên đưa ra câu hỏi cùng dạng với câu hỏi của mình ở trên.

# %% [markdown]
# Một câu hỏi có thể có là: Tiền lương trung bình ở các ngôn ngữ lập trình khác nhau, đất nước khác nhau, tình trạng học vấn của người đó... sẽ khác nhau như thế nào
#
# Trả lời được câu hỏi này sẽ phần nào giúp ta định hướng là nên tập trung học ngôn ngữ nào, có nên học lên cao hay không hay là đất nước nào ta nên đến đó để làm việc nếu có cơ hội... để có thể có tiền lương tốt hơn trong tương lai

# %% [markdown]
# ---

# %% [markdown]
# ## Tiền xử lý để chuẩn bị dữ liệu cho bước phân tích để trả lời cho câu hỏi của bạn

# %% [markdown]
# Phần này là không bắt buộc.

# %%
# YOUR CODE HERE (OPTION) 
#take all necessary columns relate to salary
all_cols = ['Country', 'DevType', 'EdLevel', 'Employment', 'LanguageWorkedWith', 'MiscTechWorkedWith',
           'NEWCollabToolsWorkedWith', 'NEWLearn', 'NEWOvertime', 'OpSys', 'PlatformWorkedWith',
           'Age', 'ConvertedComp', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro']

# %% [markdown]
# Đầu tiên, ta sẽ bỏ đi các giá trị null của cột lương là ConvertedComp, sau đó với các cột còn lại là numeric ta sẽ fillna(0) và
# tương tự fillna('unk') cho các cột không phải numeric

# %%
salary_df = survey_df[all_cols]
salary_df = salary_df.dropna(subset=['ConvertedComp'])
salary_df[['Age', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro']] = salary_df[['Age', 'WorkWeekHrs', 'YearsCode', 'YearsCodePro']].fillna(0)
salary_df.fillna('unk')
# Out:
#                    Country  \
# Respondent
# 8            United States
# 10          United Kingdom
# 11          United Kingdom
# 12                   Spain
# 13             Netherlands
# ...                    ...
# 65619              Nigeria
# 65625             Colombia
# 65629        United States
# 65630                Chile
# 65631                Japan
#
#                                                                                                         DevType  \
# Respondent
# 8                 Developer, back-end;Developer, desktop or enterprise applications;Developer, game or graphics
# 10                                               Database administrator;Developer, full-stack;Developer, mobile
# 11          Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applicatio...
# 12                                                                                Designer;Developer, front-end
# 13                                                                                 Designer;Developer, back-end
# ...                                                                                                         ...
# 65619                                                          Academic researcher;Developer, back-end;Educator
# 65625                                                                                     Developer, QA or test
# 65629                                            Developer, back-end;Developer, front-end;Developer, full-stack
# 65630                                          Developer, full-stack;Developer, QA or test;System administrator
# 65631                                                                                      Developer, front-end
#
#                                                                                        EdLevel  \
# Respondent
# 8                                                 Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 10                                             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11                                                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12                                      Some college/university study without earning a degree
# 13          Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
# ...                                                                                        ...
# 65619       Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
# 65625                                             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65629                                   Some college/university study without earning a degree
# 65630                                             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 65631                                             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                     Employment                   LanguageWorkedWith  \
# Respondent
# 8           Employed full-time                           Python;SQL
# 10          Employed full-time  HTML/CSS;Java;JavaScript;Python;SQL
# 11          Employed full-time                  C#;JavaScript;Swift
# 12          Employed full-time                  HTML/CSS;JavaScript
# 13          Employed full-time                  C;JavaScript;Python
# ...                        ...                                  ...
# 65619       Employed part-time   HTML/CSS;JavaScript;PHP;TypeScript
# 65625       Employed full-time                                  unk
# 65629       Employed full-time                                  unk
# 65630       Employed full-time                                  unk
# 65631       Employed full-time                                  unk
#
#            MiscTechWorkedWith  \
# Respondent
# 8                     Ansible
# 10                     Pandas
# 11                    Node.js
# 12                       .NET
# 13                        unk
# ...                       ...
# 65619         Cordova;Flutter
# 65625                     unk
# 65629                     unk
# 65630                     unk
# 65631                     unk
#
#                                                                                        NEWCollabToolsWorkedWith  \
# Respondent
# 8                                   Confluence;Jira;Github;Slack;Microsoft Teams;Google Suite (Docs, Meet, etc)
# 10                                                                                       Github;Microsoft Teams
# 11          Confluence;Jira;Github;Slack;Microsoft Teams;Microsoft Azure;Trello;Google Suite (Docs, Meet, et...
# 12                                                                                                       Github
# 13                                                                                                          unk
# ...                                                                                                         ...
# 65619                                                                                                    Trello
# 65625                                                                                                       unk
# 65629                                                                              Confluence;Jira;Github;Slack
# 65630                                                                                                       unk
# 65631                                                                                                       unk
#
#                         NEWLearn  \
# Respondent
# 8                    Once a year
# 10              Every few months
# 11              Every few months
# 12          Once every few years
# 13          Once every few years
# ...                          ...
# 65619                Once a year
# 65625                        unk
# 65629           Every few months
# 65630                        unk
# 65631                        unk
#
#                                                          NEWOvertime  \
# Respondent
# 8           Occasionally: 1-2 days per quarter but less than monthly
# 10                                  Often: 1-2 days per week or more
# 11                                 Rarely: 1-2 days per year or less
# 12                                 Rarely: 1-2 days per year or less
# 13                                 Rarely: 1-2 days per year or less
# ...                                                              ...
# 65619                               Often: 1-2 days per week or more
# 65625                              Rarely: 1-2 days per year or less
# 65629                                                          Never
# 65630             Sometimes: 1-2 days per month but less than weekly
# 65631                              Rarely: 1-2 days per year or less
#
#                   OpSys                  PlatformWorkedWith   Age  \
# Respondent
# 8           Linux-based                              Docker  36.0
# 10              Windows  Android;Linux;Raspberry Pi;Windows  22.0
# 11              Windows                      AWS;Heroku;iOS  23.0
# 12              Windows                   Windows;WordPress  49.0
# 13                MacOS                       MacOS;Windows  53.0
# ...                 ...                                 ...   ...
# 65619           Windows                   Windows;WordPress   0.0
# 65625               unk                                 unk   0.0
# 65629             MacOS                  Docker;Linux;MacOS  41.0
# 65630               unk                                 unk   0.0
# 65631               unk                                 unk   0.0
#
#             ConvertedComp  WorkWeekHrs  YearsCode  YearsCodePro
# Respondent
# 8                116000.0         39.0       17.0          13.0
# 10                32315.0         36.0        8.0           4.0
# 11                40070.0         40.0       10.0           2.0
# 12                14268.0         40.0        7.0           7.0
# 13                38916.0         36.0       35.0          20.0
# ...                   ...          ...        ...           ...
# 65619               984.0          4.0        3.0           2.0
# 65625             19428.0         40.0       12.0           5.0
# 65629               200.0          0.0       25.0          20.0
# 65630             15048.0         45.0        7.0           3.0
# 65631             38759.0         40.0        5.0           0.0
#
# [34452 rows x 16 columns]

# %% [markdown]
# Các quốc gia có lương trung bình cao nhất thì Mỹ vẫn là 1 quốc gia nổi trội nhất trên thế giới

# %%
salary_by_country = salary_df.groupby(['Country'], as_index=False).median()[['Country', 'ConvertedComp']]
salary_by_country = salary_by_country.sort_values('ConvertedComp', ascending=False)
salary_by_country
# Out:
#                   Country  ConvertedComp
# 151         United States       115000.0
# 136           Switzerland        98091.5
# 68                 Israel        98064.0
# 104               Nomadic        93000.0
# 3                 Andorra        88640.0
# ..                    ...            ...
# 27               Cameroon         3532.0
# 137  Syrian Arab Republic         2916.0
# 23      Brunei Darussalam         2580.0
# 133                 Sudan         2526.0
# 81                Lesotho           24.0
#
# [159 rows x 2 columns]

# %% [markdown]
# Về trình độ học vấn thì những người có bằng thạc sĩ hoặc tiến sĩ trở lên sẽ có mức lương trung bình nổi trội hơn

# %%
salary_by_edlevel = salary_df.groupby(['EdLevel'], as_index=False).median()[['EdLevel', 'ConvertedComp']]
salary_by_edlevel = salary_by_edlevel.sort_values('ConvertedComp', ascending=False)
salary_by_edlevel
# Out:
#                                                                               EdLevel  \
# 4                                          Other doctoral degree (Ph.D., Ed.D., etc.)
# 3                                     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 0                                                 Associate degree (A.A., A.S., etc.)
# 1                                        Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                              Some college/university study without earning a degree
# 2                                              I never completed any formal education
# 5                                                           Primary/elementary school
# 7  Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)
# 6                                                  Professional degree (JD, MD, etc.)
#
#    ConvertedComp
# 4        71093.0
# 3        58167.0
# 0        54455.0
# 1        54049.0
# 8        48924.0
# 2        46020.0
# 5        45272.5
# 7        40860.0
# 6        33240.0

# %% [markdown]
# Về các ngôn ngữ lập trình có mức lương trung bình cao nhất thì top 5 là Perl, Scala, Go, Rust và Ruby

# %%
salary_by_languagework = salary_df[['ConvertedComp', 'LanguageWorkedWith']]
salary_by_languagework.iloc[:, 1] = salary_by_languagework['LanguageWorkedWith'].str.split(';')
salary_by_languagework = salary_by_languagework.explode('LanguageWorkedWith')
salary_by_languagework1 = salary_by_languagework.groupby(['LanguageWorkedWith'], as_index=False).median()[['LanguageWorkedWith', 'ConvertedComp']]
salary_by_languagework1 = salary_by_languagework1.sort_values('ConvertedComp', ascending=False)
salary_by_languagework1
# Out:
# c:\program files\python36\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)
#        LanguageWorkedWith  ConvertedComp
# 15                   Perl        76263.0
# 21                  Scala        75669.0
# 6                      Go        74290.0
# 19                   Rust        73678.0
# 18                   Ruby        71093.0
# 1   Bash/Shell/PowerShell        65094.0
# 13            Objective-C        63778.0
# 8                 Haskell        60132.0
# 11                  Julia        59727.0
# 16                 Python        59454.0
# 22                  Swift        58527.0
# 23             TypeScript        57000.0
# 17                      R        56755.5
# 3                      C#        56723.0
# 20                    SQL        54049.0
# 12                 Kotlin        53700.0
# 4                     C++        53448.0
# 10             JavaScript        52942.0
# 0                Assembly        52814.0
# 7                HTML/CSS        51704.0
# 24                    VBA        51552.0
# 9                    Java        50436.0
# 2                       C        50067.5
# 14                    PHP        38916.0
# 5                    Dart        37079.0

# %% [markdown]
# ---

# %% [markdown]
# ## Phân tích dữ liệu để ra câu trả lời cho câu hỏi của bạn (2đ)

# %%
# YOUR CODE HERE
#raise NotImplementedError()
salary_by_country = salary_by_country.set_index('Country')
salary_by_country = salary_by_country.iloc[:, 0]
plt.figure(figsize = (14, 32))
plt.tick_params(labelsize=14)
plt.barh(salary_by_country.index, salary_by_country.values)
plt.xlabel('Mức lương trung bình theo đất nước', fontsize=14);

# %%
salary_by_edlevel = salary_by_edlevel.set_index('EdLevel')
salary_by_edlevel = salary_by_edlevel.iloc[:, 0]
plt.barh(salary_by_edlevel.index, salary_by_edlevel.values)
plt.xlabel('Mức lương trung bình theo trình độ học vấn', fontsize=14);

# %%
salary_by_languagework1 = salary_by_languagework1.set_index('LanguageWorkedWith')
salary_by_languagework1 = salary_by_languagework1.iloc[:, 0]
plt.figure(figsize = (12, 8))
plt.barh(salary_by_languagework1.index, salary_by_languagework1.values)
plt.xlabel('Mức lương trung bình theo ngôn ngữ lập trình', fontsize=14);
